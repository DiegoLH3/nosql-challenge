# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review the collections in our new database
coll = db.establishments

# %%
# review a document in the establishments collection
coll.find_one()
# Out:
# {'_id': ObjectId('664a5054cd2add81e82a9347'),
#  'FHRSID': 254719,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-03-24T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours = {
    'BusinessName': "Penang Flavours",
    'BusinessType': "Restaurant/Cafe/Canteen",
    'BusinessTypeID': "",
    'AddressLine1': "Penang Flavours",
    'AddressLine2': "146A Plumstead Rd",
    'AddressLine3': "London",
    'AddressLine4': "",
    'PostCode': "SE18 7DY",
    'Phone': "",
    'LocalAuthorityCode': "511",
    'LocalAuthorityName': "Greenwich",
    'LocalAuthorityWebSite': "http://www.royalgreenwich.gov.uk",
    'LocalAuthorityEmailAddress': "health@royalgreenwich.gov.uk",
    'scores': {
        'Hygiene': "",
        'Structural': "",
        'ConfidenceInManagement': ""
    },
    'SchemeType': "FHRS",
    'geocode': {
        'longitude': "0.08384000",
        'latitude': "51.49014200"
    },
    'RightToReply': "",
    'Distance': 4623.9723280747176,
    'NewRatingPending': True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavours)
# Out:
# InsertOneResult(ObjectId('664ff3825a0902e85faa9a95'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
coll.find_one({'BusinessName': 'Penang Flavours'})
# Out:
# {'_id': ObjectId('664ff3825a0902e85faa9a95'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
business_results = establishments.find(
    {'BusinessType': 'Restaurant/Cafe/Canteen'},
    {'BusinessTypeID': 1, 'BusinessType': 1}
)
for result in business_results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9347')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a934a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a934c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a934d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a934e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a934f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9350')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9351')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9356')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9359')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a935a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a935b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9365')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9368')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a936c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9377')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9379')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a937b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a937c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a937f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9380')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9385')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9386')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9388')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9389')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a938a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a938b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9391')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9392')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9395')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9399')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a939a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a939b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a939e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a93f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9402')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9403')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9408')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a940b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9410')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9412')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9413')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9418')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a941e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9420')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9426')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9433')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9435')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9436')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9437')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9443')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9446')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9447')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9449')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a944c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9459')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a945a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a945f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9465')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9467')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9469')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9470')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9475')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a947c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9481')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9482')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9483')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9485')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a948a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a948d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a948f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9490')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9491')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9494')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9495')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9496')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9499')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a949a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a949b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a949c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a949e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a94fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9500')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9508')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a950d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a950f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9511')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9514')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9517')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a951b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9521')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a952c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9538')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9542')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9560')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a956a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a956b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a956e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9571')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9574')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9582')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a95fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9603')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a960d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a960e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9611')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a961e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9623')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9624')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9629')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a962e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9639')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a963d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9641')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9642')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9651')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9657')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a965a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a965e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a965f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9662')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9663')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9673')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a967a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a967c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9682')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9686')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9687')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a968a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a968c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a968f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9691')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9692')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9693')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9694')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a969b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a969d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a969e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a96ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9700')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9701')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9707')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9709')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a970b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a970d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9713')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9714')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9716')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9717')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9718')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9719')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a971c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9721')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9723')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9724')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9726')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9733')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9734')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9737')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9738')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a973a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9740')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9741')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9742')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9744')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9746')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9748')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9749')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a974f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9752')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9754')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a975a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9764')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9767')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a977c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9780')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9782')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9789')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a978a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a978e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9792')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a97fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9803')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9804')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9805')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9806')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9807')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9808')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a980d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a980e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9819')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a981a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a981c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a981d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a981f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9821')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a982a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a982e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9830')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9835')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9837')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a983c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a983e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a983f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9842')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a984a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9850')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9856')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a985b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a985e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9860')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9864')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9867')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a986a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9872')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9876')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9879')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a987a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a987c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a987d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9881')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9887')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a988a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a988b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a988e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9895')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9898')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a989a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a989e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98de')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a98f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9902')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a990c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9914')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9919')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a991c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a991e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9921')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9929')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a992e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9935')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9936')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9938')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a993b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a993c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a993d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9941')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9944')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9949')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9956')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a9957')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a995c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5054cd2add81e82a995f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2c9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ca1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ca5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ca7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ca8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cb8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cbe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cc6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ccb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ccc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ccd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cd1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cd5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ce8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ced')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cf8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cf9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2cfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d06')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d1c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d49')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d4e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d52')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d55')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d58')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d83')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d9c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2d9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2da1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2da9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dbe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dc8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dcf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dd4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dd9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ddc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2de0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2de5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2de7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2de9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ded')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2df6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2df9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dfb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2dfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e03')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e18')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e19')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e1a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e28')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e49')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e4e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e56')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2e9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('664a5058cd2add81e82b2ea8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('664ff3825a0902e85faa9a95')}

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_results = establishments.find(
    {'BusinessType': 'Restaurant/Cafe/Canteen'},
    {'BusinessTypeID': 1, 'BusinessType': 1, '_id': 0}
)
for result in business_results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set': {'BusinessTypeID': 1}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
coll.find_one({'BusinessName': 'Penang Flavours'})
# Out:
# {'_id': ObjectId('664ff3825a0902e85faa9a95'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
len(list(establishments.find({'LocalAuthorityName': 'Dover'})))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
len(list(establishments.find({'LocalAuthorityName': 'Dover'})))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
coll.find_one()
# Out:
# {'_id': ObjectId('664a5054cd2add81e82a962e'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
coll.update_many(
    {},[
        {'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}},
        {'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}
    ]
)
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
coll.update_many(
    {},[
        {'$set': {'RatingValue': {'$toInt': '$RatingValue'}}}
    ]
)
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
list(coll.find(
    {},{'RatingValue': 1, 'geocode': 1}).limit(10)
)
# Out:
# [{'_id': ObjectId('664a5054cd2add81e82a962e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.195625, 'latitude': 51.083812}},
#  {'_id': ObjectId('664a5054cd2add81e82a962f'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.196408, 'latitude': 51.086058}},
#  {'_id': ObjectId('664a5054cd2add81e82a9630'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.194762, 'latitude': 51.085797}},
#  {'_id': ObjectId('664a5054cd2add81e82a9633'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('664a5054cd2add81e82a9634'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('664a5054cd2add81e82a9635'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('664a5054cd2add81e82a9636'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('664a5054cd2add81e82a9637'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('664a5054cd2add81e82a9638'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('664a5054cd2add81e82a9639'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}}]

# %%
# Check that the coordinates and rating value are now numbers
list(coll.find(
    {},{'RatingValue': 1, 'geocode': 1, '_id': 0}).limit(10)
)
# Out:
# [{'RatingValue': 5, 'geocode': {'longitude': 1.195625, 'latitude': 51.083812}},
#  {'RatingValue': 4, 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}},
#  {'RatingValue': 5, 'geocode': {'longitude': 1.194762, 'latitude': 51.085797}},
#  {'RatingValue': 5, 'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'RatingValue': 5, 'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'RatingValue': 4, 'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'RatingValue': 5, 'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}}]
